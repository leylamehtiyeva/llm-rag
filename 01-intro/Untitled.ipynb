# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
os.environ #

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[{'role':'user', "content": "Can I join yje course?"}]
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="gpt-4o",
#       3     messages=[{'role':'user', "content": "Can I join yje course?"}]
#       4 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...
